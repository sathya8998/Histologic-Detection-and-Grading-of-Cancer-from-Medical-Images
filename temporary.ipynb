# %%
import cv2
import random
import math

def RGTraversal(image,label):
    list1=[]
    #Iteration 
    steps=int(input("Enter the number of Steps: "))
    if steps ==0:
        while steps == 0:
            print("steps cannot be zero")
            steps=int(input("Enter the number of Steps: "))
    else:
        pass
    
#Select random seed and finding the coordinates of random seed    
    random.seed(a=100)

    random.randint(0,max(len(image)-1,len(image[0])-1))
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            if(label[i][j]>=60):
                RegionseedX=i
                RegionseedY=j
                break

    print("Coordinates of Region Seed ", RegionseedX,RegionseedY)

    coordL1=[]
    coordL2=[]
    coordL3=[]
    coordL4=[]
    coordL5=[]
#for cardinal direction i.e., N,E,S,W
    for p in range(steps):       
        
        gradx = cv2.Sobel(image,cv2.CV_64F,1,0,ksize=5)
        grady = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)
        highx=0
        highy=0
        cvc=0
        set1=[]
        set2=[]
        set3=[]
        set4=[]
        if cvc==0:
            if RegionseedX-1>=0 and RegionseedY-1>=0:
                set1.extend([RegionseedX-1,RegionseedY-1])
            else:
                pass 
            if RegionseedX-1>=0 and RegionseedY+1<=len(image[0]) - 1 :
                set1.extend([RegionseedX-1,RegionseedY+1])
            else:
                pass
            if RegionseedX-1>=0:
                set1.extend([RegionseedX-1,RegionseedY]) 
            else:
                pass
            if set1!=[]:
                for i in range(0,len(set1),2):
                    X=set1[i]
                    Y=set1[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1) ):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]

                                PX=set1[i]
                                PY=set1[i+1]
                                
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedX+1<=len(image)-1 and RegionseedY-1>=0:
                set2.extend([RegionseedX+1,RegionseedY-1])  
            else:
                pass
            if RegionseedX+1<=len(image)-1 and RegionseedY+1<=len(image[0]) - 1:
                set2.extend([RegionseedX+1,RegionseedY+1])
            else:
                pass
            if RegionseedX+1<=len(image)-1:
                set2.extend([RegionseedX+1,RegionseedY])
            else:
                pass
            if set2!=[]:
                for i in range(0,len(set2),2):
                    X=set2[i]
                    Y=set2[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]

                                PX=set2[i]
                                PY=set2[i+1]

                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedY-1>=0:
                set3.extend([RegionseedX,RegionseedY-1])   
            else:
                pass
            if set3!=[]:
                for i in range(0,len(set3),2):
                    X=set3[i]
                    Y=set3[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                        
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
                                                                

                                PX=set3[i]
                                PY=set3[i+1]
                                
                                
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedY+1<=len(image[0]) - 1:
                set4.extend([RegionseedX,RegionseedY+1])  
            else:
                pass
            if set4!=[]:
                for i in range(0,len(set4),2):
                    X=set4[i]
                    Y=set4[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]

                                PX=set4[i]
                                PY=set4[i+1]

                        else:
                            pass
                    else:
                        pass
            else:
                pass    

        RegionseedX=PX
        RegionseedY=PY
        if(highx <230 and RegionseedY>=0 and RegionseedX>=0 and RegionseedX<=(image.shape[0]-1) and RegionseedY<=(image.shape[1]-1)):
            coordL1.extend([RegionseedX,RegionseedY])
        else:
            pass

#coordinates of traversal path        
    print(coordL1)
#for first quadrant NE direction
    RegionseedY=RegionseedY-(len(image[0])-1)
    RegionseedX=RegionseedX-(len(image)-1)
    for p in range(steps):  
        
        #print(RegionseedX) 
        if(RegionseedY==0):
            gradx = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)
        else:
            gradx = cv2.Sobel(image,cv2.CV_64F,0,0,ksize=5)
        grady = cv2.Sobel(image,cv2.CV_64F,1,0,ksize=5)
        highx=0

        cvc=0
        set1=[]
        set2=[]
        set3=[]
        set4=[]
        if cvc==0:
            if RegionseedX-1>=0 and RegionseedY+1<=0:
                set1.extend([RegionseedX-1,RegionseedY+1])
            else:
                pass 
            if RegionseedX+1<=0 and RegionseedY+1<=0:
                set1.extend([RegionseedX+1,RegionseedY+1])
            else:
                pass
            if RegionseedY+1<=0:
                set1.extend([RegionseedX,RegionseedY+1]) 
            else:
                pass
            if set1!=[]:
                for i in range(0,len(set1),2):
                    X=set1[i]
                    Y=set1[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1) ):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set1[i]
                                PY=set1[i+1]
                                      
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedX-1>=0 and RegionseedY-1>=0:
                set2.extend([RegionseedX-1,RegionseedY-1])  
            else:
                pass
            if RegionseedX+1<=0 and RegionseedY-1>=0:
                set2.extend([RegionseedX+1,RegionseedY-1])
            else:
                pass
            if RegionseedY-1>=0:
                set2.extend([RegionseedX,RegionseedY-1])
            else:
                pass
            if set2!=[]:
                for i in range(0,len(set2),2):
                    X=set2[i]
                    Y=set2[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set2[i]
                                PY=set2[i+1]
        
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedX-1>=0:
                set3.extend([RegionseedX-1,RegionseedY])   
            else:
                pass
            if set3!=[]:
                for i in range(0,len(set3),2):
                    X=set3[i]
                    Y=set3[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                        
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
    
                                PX=set3[i]
                                PY=set3[i+1]
        
                                
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedX+1<=0:
                set4.extend([RegionseedX+1,RegionseedY])  
            else:
                pass
            if set4!=[]:
                for i in range(0,len(set4),2):
                    X=set4[i]
                    Y=set4[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set4[i]
                                PY=set4[i+1]
        
                        else:
                            pass
                    else:
                        pass
            else:
                pass    
                
        RegionseedX=PX
        RegionseedY=PY
        if(highx <230 and RegionseedY>=0 and RegionseedX>=0 and RegionseedX<=(image.shape[0]-1) and RegionseedY<=(image.shape[1]-1)):
                
            coordL2.extend([RegionseedX,RegionseedY])
        else:
            pass



#coordinates of traversal path        
    print(coordL2)

    #Normalize Array
    for i in range(len(coordL2)):
        if(i%2==0):
            X=coordL2[i] + image.shape[0] - 1
            coordL2[i]=X
        else:
            Y=coordL2[i] + image.shape[1] - 1
            coordL2[i]=Y  
    
#for second quadrant SE direction
    RegionseedY=RegionseedY
    RegionseedX=RegionseedX+(len(image)-1)

    for p in range(steps):  
        
        gradx = cv2.Sobel(image,cv2.CV_64F,1,0,ksize=5)
        grady = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)
        highx=0

        cvc=0
        set1=[]
        set2=[]
        set3=[]
        set4=[]
        if cvc==0:
            if RegionseedX-1>=0 and RegionseedY-1>=0:
                set1.extend([RegionseedX-1,RegionseedY-1])
            else:
                pass 
            if RegionseedX-1>=0 and RegionseedY+1<=(image.shape[1]-1):
                set1.extend([RegionseedX-1,RegionseedY+1])
            else:
                pass
            if RegionseedX-1>=0:
                set1.extend([RegionseedX-1,RegionseedY]) 
            else:
                pass
            if set1!=[]:
                for i in range(0,len(set1),2):
                    X=set1[i]
                    Y=set1[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1) ):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set1[i]
                                PY=set1[i+1]
                                      
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedX+1<=image.shape[0]-1 and RegionseedY-1>=0:
                set2.extend([RegionseedX+1,RegionseedY-1])  
            else:
                pass
            if RegionseedX+1<=image.shape[0]-1 and RegionseedY+1<=(image.shape[1]-1):
                set2.extend([RegionseedX+1,RegionseedY+1])
            else:
                pass
            if RegionseedX+1<=image.shape[0]-1:
                set2.extend([RegionseedX+1,RegionseedY])
            else:
                pass
            if set2!=[]:
                for i in range(0,len(set2),2):
                    X=set2[i]
                    Y=set2[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set2[i]
                                PY=set2[i+1]
        
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedY-1>=0:
                set3.extend([RegionseedX,RegionseedY-1])   
            else:
                pass
            if set3!=[]:
                for i in range(0,len(set3),2):
                    X=set3[i]
                    Y=set3[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                        
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
    
                                PX=set3[i]
                                PY=set3[i+1]
        
                                
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedY+1<=(image.shape[1]-1):
                set4.extend([RegionseedX,RegionseedY+1])  
            else:
                pass
            if set4!=[]:
                for i in range(0,len(set4),2):
                    X=set4[i]
                    Y=set4[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set4[i]
                                PY=set4[i+1]
        
                        else:
                            pass
                    else:
                        pass
            else:
                pass    
                
        RegionseedX=PX
        RegionseedY=PY
        if(highx <230 and RegionseedY>=0 and RegionseedX>=0 and RegionseedX<=(image.shape[0]-1) and RegionseedY<=(image.shape[1]-1)):
                
            coordL3.extend([RegionseedX,RegionseedY])
        else:
            pass
            

#coordinates of traversal path        
    print(coordL3)   
#for third mask SW direction
    RegionseedX=RegionseedX
    RegionseedY=RegionseedY
    for p in range(steps):  
        
        gradx = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)
        if(RegionseedX==len(image)-1):
            grady = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)
        else:
            grady = cv2.Sobel(image,cv2.CV_64F,0,0,ksize=5)
        highx=0

        cvc=0
        set1=[]
        set2=[]
        set3=[]
        set4=[]
        if cvc==0:
            if RegionseedX-1>=0 and RegionseedY-1>=0:
                set1.extend([RegionseedX-1,RegionseedY-1])
            else:
                pass 
            if RegionseedX-1>=0 and RegionseedY+1<=(image.shape[1]-1):
                set1.extend([RegionseedX-1,RegionseedY+1])
            else:
                pass
            if RegionseedX-1>=0:
                set1.extend([RegionseedX-1,RegionseedY]) 
            else:
                pass
            if set1!=[]:
                for i in range(0,len(set1),2):
                    X=set1[i]
                    Y=set1[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1) ):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set1[i]
                                PY=set1[i+1]
                                      
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedX+1<=image.shape[0]-1 and RegionseedY-1>=0:
                set2.extend([RegionseedX+1,RegionseedY-1])  
            else:
                pass
            if RegionseedX+1<=image.shape[0]-1 and RegionseedY+1<=(image.shape[1]-1):
                set2.extend([RegionseedX+1,RegionseedY+1])
            else:
                pass
            if RegionseedX+1<=image.shape[0]-1:
                set2.extend([RegionseedX+1,RegionseedY])
            else:
                pass
            if set2!=[]:
                for i in range(0,len(set2),2):
                    X=set2[i]
                    Y=set2[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set2[i]
                                PY=set2[i+1]
        
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedY-1>=0:
                set3.extend([RegionseedX,RegionseedY-1])   
            else:
                pass
            if set3!=[]:
                for i in range(0,len(set3),2):
                    X=set3[i]
                    Y=set3[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                        
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
    
                                PX=set3[i]
                                PY=set3[i+1]
        
                                
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedY+1<=(image.shape[1]-1):
                set4.extend([RegionseedX,RegionseedY+1])  
            else:
                pass
            if set4!=[]:
                for i in range(0,len(set4),2):
                    X=set4[i]
                    Y=set4[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set4[i]
                                PY=set4[i+1]
        
                        else:
                            pass
                    else:
                        pass
            else:
                pass    
                
        RegionseedX=PX
        RegionseedY=PY
        if(highx <230 and RegionseedY>=0 and RegionseedX>=0 and RegionseedX<=(image.shape[0]-1) and RegionseedY<=(image.shape[1]-1)):
                
            coordL4.extend([RegionseedX,RegionseedY])
        else:
            pass


            
#coordinates of traversal path        
    print(coordL4)

#Normalize Array
    for i in range(len(coordL4)):
        if(i%2==0):
            X=coordL4[i] - image.shape[0] + 1
            coordL4[i]=X
        else:
            Y=coordL4[i]
            coordL4[i]=Y 

#Forth traverse NW direction
    RegionseedY = RegionseedY + (len(image[0])-1)
    RegionseedX= RegionseedX - (len(image)-1)
    for p in range(steps):  
        
        if(RegionseedY==len(image[0])-1):
            gradx = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)
        else:
            gradx = cv2.Sobel(image,cv2.CV_64F,0,0,ksize=5)
        grady = cv2.Sobel(image,cv2.CV_64F,1,0,ksize=5)
        highx=0

        cvc=0
        set1=[]
        set2=[]
        set3=[]
        set4=[]
        if cvc==0:
            if RegionseedX-1>=0 and RegionseedY+1<=0:
                set1.extend([RegionseedX-1,RegionseedY+1])
            else:
                pass 
            if RegionseedX+1<=0 and RegionseedY+1<=(len(image[0])-1):
                set1.extend([RegionseedX+1,RegionseedY+1])
            else:
                pass
            if RegionseedY+1<=(len(image[0])-1):
                set1.extend([RegionseedX,RegionseedY+1]) 
            else:
                pass
            if set1!=[]:
                for i in range(0,len(set1),2):
                    X=set1[i]
                    Y=set1[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1) ):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set1[i]
                                PY=set1[i+1]
                                      
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedX-1>=0 and RegionseedY-1>=0:
                set2.extend([RegionseedX-1,RegionseedY-1])  
            else:
                pass
            if RegionseedX+1<=0 and RegionseedY-1>=0:
                set2.extend([RegionseedX+1,RegionseedY-1])
            else:
                pass
            if RegionseedY-1>=0:
                set2.extend([RegionseedX,RegionseedY-1])
            else:
                pass
            if set2!=[]:
                for i in range(0,len(set2),2):
                    X=set2[i]
                    Y=set2[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
       
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set2[i]
                                PY=set2[i+1]
        
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedX-1>=0:
                set3.extend([RegionseedX-1,RegionseedY])   
            else:
                pass
            if set3!=[]:
                for i in range(0,len(set3),2):
                    X=set3[i]
                    Y=set3[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                        
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
    
                                PX=set3[i]
                                PY=set3[i+1]
        
                                
                        else:
                            pass
                    else:
                        pass
            else:
                pass
            if RegionseedX+1<=(len(image)-1):
                set4.extend([RegionseedX+1,RegionseedY])  
            else:
                pass
            if set4!=[]:
                for i in range(0,len(set4),2):
                    X=set4[i]
                    Y=set4[i+1]
                    if cvc==0:
                        if (X>=0 and X<=(image.shape[0]-1) and Y>=0 and Y<=(image.shape[1]-1)):
                            if(image[X][Y]>=highx):
                                highx=image[X][Y]
        
                                PX=set4[i]
                                PY=set4[i+1]
        
                        else:
                            pass
                    else:
                        pass
            else:
                pass    
                
        RegionseedX=PX
        RegionseedY=PY
        if(highx <230 and RegionseedY>=0 and RegionseedX>=0 and RegionseedX<=(image.shape[0]-1) and RegionseedY<=(image.shape[1]-1)):
                
            coordL5.extend([RegionseedX,RegionseedY])
        else:
            pass

#coordinates of traversal path        
    print(coordL5)
    for i in range(len(coordL5)):
        if(i%2==0):
            X=coordL5[i] - image.shape[0] + 1
            coordL5[i]=X
        else:
            Y=coordL5[i] - image.shape[1] + 1
            coordL5[i]=Y
